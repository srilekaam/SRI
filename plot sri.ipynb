# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
product=["milk","biscuits","pizza","ice cream"]
price=[26,20,199,150]
plt.plot(product,price)
plt.show()
